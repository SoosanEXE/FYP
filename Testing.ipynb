# %% [markdown]
# # Testing Datapreprocess modules

# %%
from DataPreprocess import BinaryClassMapping, Encoding, FeatureSelection, Scaling
import pandas as pd

# %%
df = pd.read_csv("/FYP/DataSets/iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = Scaling.Scaling.scaling(df, df.select_dtypes(['float64', 'int64']).columns)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0        0.222222     0.625000      0.067797     0.041667     setosa
# 1        0.166667     0.416667      0.067797     0.041667     setosa
# 2        0.111111     0.500000      0.050847     0.041667     setosa
# 3        0.083333     0.458333      0.084746     0.041667     setosa
# 4        0.194444     0.666667      0.067797     0.041667     setosa
# ..            ...          ...           ...          ...        ...
# 145      0.666667     0.416667      0.711864     0.916667  virginica
# 146      0.555556     0.208333      0.677966     0.750000  virginica
# 147      0.611111     0.416667      0.711864     0.791667  virginica
# 148      0.527778     0.583333      0.745763     0.916667  virginica
# 149      0.444444     0.416667      0.694915     0.708333  virginica
#
# [150 rows x 5 columns]

# %%
df_copy = df.copy()
df_copy = Encoding.Encoding.Labencoding(df_copy)
df_copy
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0        0.222222     0.625000      0.067797     0.041667        0
# 1        0.166667     0.416667      0.067797     0.041667        0
# 2        0.111111     0.500000      0.050847     0.041667        0
# 3        0.083333     0.458333      0.084746     0.041667        0
# 4        0.194444     0.666667      0.067797     0.041667        0
# ..            ...          ...           ...          ...      ...
# 145      0.666667     0.416667      0.711864     0.916667        2
# 146      0.555556     0.208333      0.677966     0.750000        2
# 147      0.611111     0.416667      0.711864     0.791667        2
# 148      0.527778     0.583333      0.745763     0.916667        2
# 149      0.444444     0.416667      0.694915     0.708333        2
#
# [150 rows x 5 columns]

# %%
nfs = FeatureSelection.FeatureSelection.select_features(df.drop('species', axis=1), df['species'],'species', 2)
nfs
# Out:
# ['petal_length', 'petal_width', 'species']
