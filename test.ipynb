# %%
import pandas as pd
from DataSets import constants as paths
from DataPreprocess import constants
from DataPreprocess.Scaling import Scaling
from DataPreprocess.BinaryClassMapping import BinMap
from DataPreprocess.Encoding import Encoding
from DataPreprocess.FeatureSelection import FeatureSelection

# %%
df = pd.read_csv("/home/soosan/fyp/FYP/DataSets/KDDTrain+.txt", header=None, names=constants.COL_NAMES)

# %%
df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#    difficulty_level  attack_class
# 0                20             0
# 1                15             0
# 2                19             1
# 3                21             0
# 4                21             0
#
# [5 rows x 43 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = BinMap(df)
df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#    difficulty_level  attack_class
# 0                20             0
# 1                15             0
# 2                19             1
# 3                21             0
# 4                21             0
#
# [5 rows x 43 columns]

# %%
X = df.drop('attack_class', axis=1)
y = df['attack_class']
nfs = FeatureSelection.select_features(X, y)
nfs
# Out:
# An Exception Occured! could not convert string to float: 'tcp'

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['protocol_type', 'service', 'flag', 'label'], dtype='object')

# %%
class test:
    def __init__():
        return
a = test
t = Encoding.OHencoding(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [19], line 5
#       3         return
#       4 a = test
# ----> 5 t = Encoding.OHencoding(a)
#
# File ~/fyp/FYP/DataPreprocess/Encoding.py:18, in OHencoding(df)
#      14 def __init__(self) -> None:
#      15     return
#      17 @staticmethod
# ---> 18 def OHencoding(df):
#      19     try:
#      20         if type(df) is not DataFrame:
#
# AttributeError: type object 'test' has no attribute 'select_dtypes'

# %%
df = BinMap(df)
df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# 0               0       0    0  ...                    0.03
# 1               0       0    0  ...                    0.60
# 2               0       0    0  ...                    0.05
# 3               0       0    0  ...                    0.00
# 4               0       0    0  ...                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate    label  difficulty_level  attack_class
# 0                      0.00   normal                20             0
# 1                      0.00   normal                15             0
# 2                      0.00  neptune                19             1
# 3                      0.01   normal                21             0
# 4                      0.00   normal                21             0
#
# [5 rows x 44 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [label]
# Index: []
